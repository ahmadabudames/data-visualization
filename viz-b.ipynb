# %%
from matplotlib import pyplot as plt
import seaborn as sns
from calendar import month_abbr

# %%
sns.load_dataset('planets')
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %% [markdown]
# # Load the data

# %%
sns.get_dataset_names() 
df = sns.load_dataset("planets")
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
number = df[df.number >= 1]
distance_by_method = number.groupby("method", as_index=False).distance.mean()
sns.barplot(x="method",y="distance",data=distance_by_method)
distance_by_method
# Out:
#                           method     distance
# 0                     Astrometry    17.875000
# 1      Eclipse Timing Variations   315.360000
# 2                        Imaging    67.715937
# 3                   Microlensing  4144.000000
# 4  Orbital Brightness Modulation  1180.000000
# 5                  Pulsar Timing  1200.000000
# 6    Pulsation Timing Variations          NaN
# 7                Radial Velocity    51.600208
# 8                        Transit   599.298080
# 9      Transit Timing Variations  1104.333333

# %% [markdown]
# # count for the number

# %%
sns.countplot(x="number",data=df)
# Out:
# <AxesSubplot:xlabel='number', ylabel='count'>

# %% [markdown]
# # relplot for the year and the distance

# %%
sns.relplot(x="year",y="distance",data=df)

# %% [markdown]
# # Implot for year and the number

# %%
sns.lmplot(x="year",y="number",data=df)

# %% [markdown]
# # barplot for year and the mass

# %%
sns.barplot(x="year",y="mass", data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='mass'>
